# %% [markdown]
# <a href="https://colab.research.google.com/github/Asthagupta622/Astha1gupta622.github.io/blob/main/Excercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd

# %%
titles = pd.read_csv('/content/titles.csv')
titles.head()
# Out:
#                           title  year
# 0                    El plebeyo  1953
# 1  Atoski vrtovi - preobrazenje  1989
# 2                Mateegy norkos  2006
# 3                 Lanka Dahanam  1936
# 4                       Acciaio  1933

# %%
titles.title.value_counts().head(1)
# Out:
# title
# Hamlet    34
# Name: count, dtype: int64

# %%
most=titles[titles.year //10==193]
most.head()
# Out:
#              title  year
# 3    Lanka Dahanam  1936
# 4          Acciaio  1933
# 8     Oklahoma Jim  1931
# 68     Blackmailer  1936
# 90  Papacito lindo  1939

# %%
t=titles['decade']=titles.year // 10*10
t.value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
t=titles
t=t[t.title=='Hamlet']
(t.year // 10 * 10).value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
path='/content/cast.csv'
casting =pd.read_csv(path,on_bad_lines='skip')
casting.head()
# Out:
# <ipython-input-34-2b8a08b59666>:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   casting =pd.read_csv(path,on_bad_lines='skip')
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c=casting
c=c[c.character=='Rustler']
c['year']=pd.to_numeric(c['year'])
(c.year // 10 * 10).value_counts().sort_index().plot(kind='bar')
# Out:
# <ipython-input-35-cc9bf42c86c7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['year']=pd.to_numeric(c['year'])
# <Axes: xlabel='year'>

# %%
c=casting
c=c[c.character=='Hamlet']
c['year']=pd.to_numeric(c['year'])
(c.year // 10 * 10).value_counts().sort_index().plot(kind='bar')
# Out:
# <ipython-input-36-c6e196cf4fb4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['year']=pd.to_numeric(c['year'])
# <Axes: xlabel='year'>

# %%
casting.character.value_counts().head(11)
# Out:
# character
# Himself        24074
# Policeman       7813
# Doctor          7614
# Extra           7599
# Reporter        7421
# Townsman        7344
# Bartender       6441
# Waiter          6320
# Henchman        5903
# Dancer          5647
# Party Guest     5322
# Name: count, dtype: int64

# %%
c=casting
c[c.character=='Himself'].name.value_counts().head(10)
# Out:
# name
# Adolf Hitler          182
# John F. Kennedy        70
# Winston Churchill      48
# George W. Bush         48
# Martin Luther King     46
# Bill Clinton           44
# Ron Jeremy             40
# Muhammad Ali           36
# Billy Graham           30
# Lyndon Johnson         28
# Name: count, dtype: int64

# %% [markdown]
# Which actors or actresses appeared in the most movies in the year 1945?

# %%
c[c.year==1945].name.value_counts().head()
# Out:
# name
# Sam (II) Harris        62
# Horace B. Carpenter    46
# Budd Buster            44
# Byron Foulger          42
# James Flavin           40
# Name: count, dtype: int64

# %% [markdown]
# Which actors or actresses appeared in the most movies in the year 1985?

# %%
c[c.year==1985].name.value_counts().head()
# Out:
# name
# Danny Denzongpa    22
# Vikas Anand        18
# Pat (II) Fraley    18
# Lalu Alex          18
# Joey de Leon       14
# Name: count, dtype: int64

# %%
casting.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
titles.head()
# Out:
#                           title  year  decade
# 0                    El plebeyo  1953    1950
# 1  Atoski vrtovi - preobrazenje  1989    1980
# 2                Mateegy norkos  2006    2000
# 3                 Lanka Dahanam  1936    1930
# 4                       Acciaio  1933    1930

# %% [markdown]
# Plot how many roles Mammootty has played in each year of his career.

# %%
c=casting
c[c.name=='Mammootty'].year.value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
c=casting
c[c.character.str.startswith('Patron in',na=True)].character.value_counts().head(10)
# Out:
# character
# Patron in Frisky Rabbit         10
# Patron in Chinese Restaurant     8
# Patron in Billiard Parlor        6
# Patron in Club                   4
# Patron in the Coffee House       4
# Patron in booth                  4
# Patron in restaurant             4
# Patron in Quiet Bar              2
# Patron in Night Club             2
# Patron in Macy's Lunchroom       2
# Name: count, dtype: int64

# %%
c[c.character.str.startswith('Science ',na=True)].value_counts().sort_index()
# Out:
# title                             year  name                    type   character                 n
# 500 MPH Storm                     2013  Lawrence Kruckeberg     actor  Science Tech #2           12.0    2
# A Wreck, a Tangle                 2000  Peter Carroll           actor  Science Voice Over        6.0     2
# An Invisible Sign                 2010  Brandon Jeffers         actor  Science Kid #1            25.0    2
# Apollo 13                         1995  Jack Conley             actor  Science Reporter          69.0    2
#                                         Jeffrey Kluger          actor  Science Reporter          70.0    2
# Arranged                          2007  Tzvi Frankel            actor  Science Date              40.0    2
# Benavides Born                    2011  Ruperto Canales III     actor  Science Teacher           27.0    2
# Beyond the Heavens                2013  Brian Copping           actor  Science Teacher           7.0     2
# ...
